# %%
import numpy as np

# %%
list = [2, 3, 5]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(list)

# %%
x = ('0.01', '0.1', '0.25')

# %%
plt.bar(x, list)
# Out:
# <BarContainer object of 3 artists>
